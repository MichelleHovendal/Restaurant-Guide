# %%
def filters(df):
    
    business_df = df.copy()
    
    # State
    state_value = select_state.value
    states = ['All', 'Massachusetts', 'Florida', 'Oregon', 'British Columbia', 'Georgia', 'Texas', 
             'Ohio', 'Colorado', 'Washington', 'Kansas', 'Kentucky']
    
    if state_value != states[0]:
        business_df = business_df[business_df['state_name'] == state_value]
        
    # city
#     city_value = select_city.value
#     cities = ['All', 'Boulder', 'Atlanta', 'Louisville', 'Portland', 'Austin', 'Niwot', 'Woburn', 'Malden', 'Allston', 'Boston', 'Watertown', 'Waltham',
#        'Natick', 'Cambridge', 'Salem', 'Orlando', 'Winter Park', 'Altamonte Springs', 'Lake Mary', 'Edgewood', 'East Point',
#        'Longwood', 'Lee Vista', 'Sanford', 'Lake Buena Vista', 'Belle Isle', 'Orange City', 'Apopka', 'Maitland', 'Casselberry',
#        'Columbus', 'ORLANDO', 'Titusville', 'Kissimmee', 'Cocoa', 'Chuluota', 'Oviedo', 'Debary', 'KISSIMMEE', 'Saint Cloud',
#        'Merritt Island', 'Mount Dora', 'Waterford Lakes', 'Ocoee', 'Windermere', 'Winter Garden', 'Clermont', 'Fern Park', 'Dunwoody',
#        'St. Cloud', 'Clayton', 'Pine Castle', 'Vancouver', 'Bedford', 'Burlington', 'Lexington', 'Wellesley', 'Needham', 'Sandy Springs',
#        'Port Coquitlam', 'Lake Oswego', 'Tigard', 'Grandview Heights', 'Brighton', 'Braintree', 'Chelsea', 'Smyrna', 'Gahanna',
#        'Lynnfield', 'Lynn', 'Stoneham', 'Medford', 'Winthrop', 'Bexley', 'Tewksbury', 'Somerville', 'Norwood', 'Hingham', 'Dorchester',
#        'Jamaica Plain', 'Brookline', 'Wilmington', 'Danvers', 'Weymouth', 'Quincy', 'Westwood', 'Canton', 'Beverly', 'Revere', 'Saugus',
#        'Dedham', 'Walpole', 'Stoughton', 'Boston-Fenway', 'Chestnut Hill', 'Wakefield', 'Newton', 'West Roxbury', 'Newtonville', 'Concord',
#        'Belmont', 'Decatur', 'Champions Gate', 'South Boston', 'Tucker', 'Doraville', 'Everett', 'Melrose', 'Arlington', 'Winchester',
#        'Beaverton', 'Dublin', 'Worthington', 'Hilliard', 'Lewis Center', 'Upper Arlington', 'Powell', 'College Park', 'Richmond',
#        'Framingham', 'SANFORD', 'Hapeville', 'West Newton', 'Deltona', 'Marblehead', 'Cohasset', 'East Weymouth', 'Hull', 'Norwell',
#        'North Weymouth', 'Rockland', 'Milton', 'Marietta', 'Aloha', 'Hillsboro', 'Celebration', 'Roslindale', 'Happy Valley',
#        'Clackamas', 'Swampscott', 'Tualatin', 'Peabody', 'Middleton', 'Weston', 'Wayland', 'North Reading', 'Davenport', 'North Quincy',
#        'Chamblee', 'Westerville', 'Charlestown', 'CLERMONT', 'Montverde', 'Winter Springs', 'Milwaukie', 'Oregon City', 'Gresham', 'Camas',
#        'Burnaby', 'Coquitlam', 'Gladstone', 'Oak Grove', 'Gold Hill', 'Lafayette', 'OVIEDO', 'DeBary', 'Heathrow', 'Urbancrest',
#        'Commercial Point', 'Grove City', 'Delaware', 'Lakeway', 'Pickerington', 'Reading', 'Randolph', 'Vinings', 'Norcross',
#        'Scottdale', 'Brookhaven', 'Buda', 'Kyle', 'Sunset Valley', 'Driftwood', 'West Lake Hills', 'Bee Caves', 'Bee Cave',
#        'Pflugerville', 'Manor', 'Beecave', 'San Marcos', 'Billerica', 'Roxbury', 'Mattapan', 'Newton Centre', 'South Weymouth',
#        'Roxbury Crossing', 'Sudbury', 'North Billerica', 'COCOA', 'Surrey', 'North Vancouver', 'East Boston',
#        'Jeffries Point / Airport', 'Pataskala', 'Lockbourne', 'Whitehall', 'Canal Winchester', 'Alamonte Springs', 'Poinciana', 'ST. CLOUD',
#        'St Cloud', 'Fern park', 'Needham Heights', 'Hyde Park', 'Hollbrook', 'Brockton', 'Dripping Springs', 'West Linn',
#        'Clarkston', 'Happy valley', 'Plain City', 'Port Moody', 'New Westminster', 'Delta', 'RichMond', 'Bowen Island',
#        'West Vancouver', 'PORTLAND', 'Newton Highlands', 'East Walpole', 'Reynoldsburg', 'Wellesley Hills', 'NEW WESTMINSTER', 'Superior',
#        'Sunbury', 'Blacklick', 'Groveport', 'Jackson', 'Del Valle', 'New Albany', 'BURNABY', 'RICHMOND', 'Carlisle', 'Volente',
#        'Mableton', 'Stone Mountain', 'Buckhead', 'Avondale Estates', 'Four Corners', 'Sandy Spring', 'Holbrook', 'Harmony',
#        'Eatonville', 'Championsgate', 'ChampionsGate', 'Galena','DAVENPORT', 'Ellsworth', 'Point Venture', 'AUSTIN', 'CASSELBERRY',
#        'Ladner', 'Alafaya', 'Dover', 'Avon', 'Leander', 'East boston','Galloway', 'Obetz', 'Lithopolis', 'Ashville', 'Osteen',
#        'Forest Park', 'Lake City', 'Johnstown', 'West Jefferson', 'HOLB', 'Mount Sterling', 'DEBARY', 'Ellenwood', 'King City', 'Damascus',
#        'London', 'Liberty', 'Conley', 'Collegepark', 'Port Saint John', 'TITUSVILLE', 'Carroll', 'Sorrento', 'Berkshire', 'Lithonia',
#        'Bay Lake', 'South Bloomfield', 'Rockledge', 'Nahant', 'Englewood', 'Orland', 'Austell', 'Fairview', 'Orlanto', 'Northeast Orlando',
#        'Miami Beach', 'Springfield', 'Golden', 'North Andover']
    
#     if city_value != cities[0]:
#         business_df = business_df[business_df['city'] == city_value]
        
#     # kitchen
#     kitchen_value = select_kitchen.value
#     kitchen = ['All', 'thai', 'chinese','japanese','korean','indian','american',
#                  'caribbean','italian','mediterranean','mexican', 'cajun',
#                 'vietnamese','greek']
    
#     if kitchen_value != kitchen[0]:
#         business_df = business_df[business_df['cat_kitchen'] == kitchen_value]
        
#     # type
#     type_value = select_type.value
#     types = ['All','Food','Nightlife','Bars','Sandwiches','Pizza','Breakfast & Brunch', 'Fast Food',
#             'Burgers','Salad', 'Buffet', 'Cafes','Coffee & Tea', 'Vegetarian', 'Steakhouse', 'Sushi Bars',
#             'Diners','Wine Bars']
    
#     if type_value != types[0]:
#         business_df = business_df[business_df['cat_typen'] == type_value]
       
    ##### Preparing with long/lat coordinates 
    # coordinates for plot
    business_df['coordinates'] = list(zip(business_df['latitude'], business_df['longitude']))
    # Obtain list of mercator coordinates
    mercators = [x_coord(x, y) for x, y in business_df['coordinates'] ]

    # Create mercator column in our df
    business_df['mercator'] = mercators
    # Split that column out into two separate columns - mercator_x and mercator_y
    business_df[['mercator_x', 'mercator_y']] = business_df['mercator'].apply(pd.Series)
    
    # Make data dict and columnsource
    df_dict_filter = business_df.to_dict('list')
    source = ColumnDataSource(df_dict_filter)

    w = 80

    div_title = Div(text="<b> Restaurant matching Preferences: {} </b>".format(len(business_df)),
               style={'font-size': '150%'})
    
    columns = [
        TableColumn(field="name", title="Restaurant Name", width=w),
        TableColumn(field="stars", title="Stars", width=w),
        TableColumn(field="state_name", title="State", width=w),
#         TableColumn(field="city", title="Cite", width=w),
#         TableColumn(field="cat_kitchen", title="Kitchen", width=w),
#         TableColumn(field="cat_type", title="Type", width=w)
    ]
    table = DataTable(source=source, columns=columns,
                           width=800, height=180, fit_columns=False)
    
    
    #Map layout of North America
    lat, long = 48.1667, 100.1667
    x, y = x_coord(lat, long)
    
    chosentile = get_provider(Vendors.CARTODBPOSITRON)
    
    tooltips = [("Restaurant","@name"), ("Stars", "@star")]

    p = figure(x_axis_type="mercator", y_axis_type="mercator", 
           x_axis_label = 'Longitude', y_axis_label = 'Latitude', 
           tooltips = tooltips, plot_width=800, plot_height=600, 
           toolbar_location='below', tools="pan,wheel_zoom,reset", 
            active_scroll='auto')

    p.add_tile(chosentile)

    p.circle(x = 'mercator_x', y = 'mercator_y', color = 'lightblue', source=source, 
         size=5, fill_alpha = 0.7)
    
    return table, p, div_title

# %%
def update_fig(attr, old, new):
    table, p, div_title = filters(df_new)
    layout.children[2].children[0] = table
    layout.children[2].children[1] = p
    layout.children[0] = div_title

div_subtitle = Div(text="<i> Filter with the data and find your favorite restaurant </i>")
# User select: State
div_state = Div(text="<b> Select State </b>")
state = ['All']+df['state_name'].unique().tolist()
select_state = Select(options=state, value=state[0]) #by default All is chosen
select_state.on_change('value', update_fig)

# # User select: City
# div_city = Div(text="<b> Select City </b>")
# city = ['All']+df['city'].unique().tolist()
# select_city = Select(options=city, value=city[0]) #by default All is chosen
# select_city.on_change('value', update_fig)

# User select: Kitchen
# div_kitchen = Div(text="<b> Select Kitchen </b>")
# kitchen = ['All']+df['cat_kitchen'].unique().tolist()
# select_kitchen = Select(options=kitchen, value=kitchen[0]) #by default All is chosen
# select_kitchen.on_change('value', update_fig)

# # User select: Type
# div_type = Div(text="<b> Select Type </b>")
# types = ['All']+df['cat_type'].unique().tolist()
# select_type = Select(options=types, value=types[0]) #by default All is chosen
# select_type.on_change('value', update_fig)

#build the plot
table, p, div_title = filters(df)

# Combine all controls to get in column
col_tab_plot = row(table, p, height=200, width=1000)
# col_filters = column(div_state, div_city, div_kitchen, div_type, width=250)
col_filters = column(div_state, width=250)

# Layout
layout = column(div_title, div_subtitle, col_tab_plot, row(col_filters)) 
#it is possible to add multiple col_filters in the row(), you just need to specify it above

curdoc().add_root(layout)
curdoc().title = "Test"

show(layout)

# %% [markdown]
# Bokeh plot - week 8

# %%
#pivot dataframe
df_pivot = group_state.pivot_table(values = 'Counts', index='state', columns='cat_kitchen')
source = ColumnDataSource(df_pivot)

# %%
#define bokeh figure
p = figure(x_range = FactorRange(factors=df_pivot.index.to_list()), x_axis_label = 'State',
           y_axis_label='Count', title='Lala', plot_width = 1400, plot_height = 800,
          toolbar_location=None, tools="")

# %%
bar ={} # to store vbars
items = []
### here we will do a for loop:
for indx, i, color in zip(range(len(df_pivot.columns.to_list())), df_pivot.columns.to_list(), Category20c[13]):
    bar[i] = p.vbar(x='state',  top=i, source=source,
                    muted_alpha=0.2, muted = False,
                    color=color, muted_color = color,
                   width=0.5)
    items.append((i, [bar[i]]))

# %%
#add legend
legend = Legend(items=items)
p.add_layout(legend,'left')

# %%
#Show plot
p.xaxis.major_label_orientation = "vertical"
p.legend.click_policy="mute"
show(p)
